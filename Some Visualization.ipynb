# %% [markdown]
# ![صورة واتساب بتاريخ 1445-10-08 في 08.09.49_35edc638.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **NexGenBank🏛🚀**

# %% [markdown]
# # **Our goal** is to reduce churn rate and enhance user engagement by understanding user behavior and product usage patterns.

# %%
# !pip install google-cloud-bigquery

# %% [markdown]
# ##**Notifications Table**✨

# %%
# your code here  # notifications Table
from google.colab import auth
import pandas as pd
# Will collect your credentials
auth. authenticate_user ()
# Query Bigquery
query = "SELECT * FROM `metal-scholar-413922.Neo_bank.notifications`"
df = pd.read_gbq(query, project_id="metal-scholar-413922")
df.head()
# Out:
#       user_id              reason channel status        date
# 0   user_7129  METAL_RESERVE_PLAN     SMS   SENT  2018-10-10
# 1   user_7075  METAL_RESERVE_PLAN     SMS   SENT  2018-10-11
# 2   user_2227  METAL_RESERVE_PLAN     SMS   SENT  2018-10-14
# 3   user_7802  METAL_RESERVE_PLAN     SMS   SENT  2018-10-14
# 4  user_10466  METAL_RESERVE_PLAN     SMS   SENT  2018-10-15

# %% [markdown]
# ##Python Libraries📚

# %%
#DATA  VISUALIZATION
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.pyplot as plt
#DATA MANIPULATION
import pandas as pd

# %% [markdown]
# count of each unique value in the 'reason' column

# %%
df['reason'].value_counts()
# Out:
# reason
# REENGAGEMENT_ACTIVE_FUNDS               35835
# FIFTH_PAYMENT_PROMO                     23027
# NO_INITIAL_CARD_USE                     11219
# NO_INITIAL_CARD_ORDER                   11136
# METAL_GAME_START                         8175
# LOST_CARD_ORDER                          6141
# NO_INITIAL_FREE_PROMOPAGE_CARD_ORDER     5458
# JOINING_ANNIVERSARY                      4158
# ONBOARDING_TIPS_ACTIVATED_USERS          3144
# MADE_MONEY_REQUEST_NOT_SPLIT_BILL        2438
# BLACK_FRIDAY                             2106
# ENGAGEMENT_SPLIT_BILL_RESTAURANT         1879
# METAL_RESERVE_PLAN                       1232
# PREMIUM_ENGAGEMENT_INACTIVE_CARD         1124
# WELCOME_HOME                              945
# PREMIUM_ENGAGEMENT_FEES_SAVED             678
# PUMPKIN_PAYMENT_NOTIFICATION              652
# Name: count, dtype: int64

# %%
reason_counts = df['reason'].value_counts()

# %% [markdown]
# ## Reasons Distribution 📊

# %% [markdown]
# bar chart showing the distribution of reasons and the count of each.

# %%
reason_counts = df['reason'].value_counts()
plt.figure(figsize=(10, 6))
reason_counts.plot(kind='bar', color='skyblue')
plt.title('Reasons Distribution')
plt.xlabel('Reason')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# the count of each unique value in the 'channel' column

# %%
df['channel'].value_counts()
# Out:
# channel
# EMAIL    59160
# PUSH     57310
# SMS       2877
# Name: count, dtype: int64

# %% [markdown]
# ##Channel Distribution 📊

# %%
channel_counts = df['channel'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(channel_counts, labels=channel_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Channel Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# the count of each unique value in the 'channel' column

# %%
df['status'].value_counts()
# Out:
# status
# SENT      89452
# FAILED    29895
# Name: count, dtype: int64

# %% [markdown]
# ## Status Distribution📊

# %%
plt.figure(figsize=(8, 6))
status_counts = df['status'].value_counts()
status_counts.plot(kind='bar', color='salmon')
plt.title('Status Distribution')
plt.xlabel('Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Age_categories'], df['avg_transactions'])
plt.title('Average Transactions by Age Category')
plt.xlabel('Age Category')
plt.ylabel('Average Transactions')
plt.show()

# %% [markdown]
# ## Transaction  Table✨

# %%
# your code here  # transaction  Table
from google.colab import auth
import pandas as pd
# Will collect your credentials
auth. authenticate_user ()
# Query Bigquery
query = "SELECT * FROM `metal-scholar-413922.Neo_bank.transactions`"
df = pd.read_gbq(query, project_id="metal-scholar-413922")
df.head()
# Out:
#         transaction_id transactions_type transactions_currency  amount_usd  \
# 0  transaction_1755477      CARD_PAYMENT                   AED       12.19
# 1      transaction_588      CARD_PAYMENT                   AED      338.90
# 2      transaction_905      CARD_PAYMENT                   AED        4.55
# 3     transaction_1107      CARD_PAYMENT                   AED       15.79
# 4  transaction_1755437      CARD_PAYMENT                   AED        4.13
#
#   transactions_state ea_cardholderpresence ea_merchant_mcc ea_merchant_city  \
# 0          COMPLETED                 FALSE            4111            Dubai
# 1          COMPLETED                 FALSE            5651            Dubai
# 2          COMPLETED                 FALSE            5912        Abu Dhabi
# 3          COMPLETED                 FALSE            5411              Dxb
# 4          COMPLETED                  TRUE            5812            Dubai
#
#   ea_merchant_country direction     user_id created_date
# ...

# %% [markdown]
# ##Users Table✨

# %%
# your code here  # Table
from google.colab import auth
import pandas as pd
# Will collect your credentials
auth. authenticate_user ()
# Query Bigquery
query = "SELECT * FROM `metal-scholar-413922.Neo_bank.users`"
df = pd.read_gbq(query, project_id="metal-scholar-413922")
df.head()
# Out:
#       user_id  age Age_categories country            city  \
# 0   user_3894   23            20s      CH          Zurich
# 1  user_16796   24            20s      FR           Brest
# 2  user_16509   24            20s      LT         Vilnius
# 3   user_1734   24            20s      LT              46
# 4   user_7042   24            20s      PL  Janów lubelski
#
#    user_settings_crypto_unlocked      plan  \
# 0                              0  STANDARD
# 1                              0  STANDARD
# 2                              0  STANDARD
# 3                              0  STANDARD
# 4                              1  STANDARD
#
#    attributes_notifications_marketing_push  \
# 0                                      1.0
# 1                                      0.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
#
#    attributes_notifications_marketing_email  num_contacts  num_referrals  \
# ...

# %% [markdown]
# ### Calculate the churn rate per user

# %% [markdown]
# user table

# %%
print(df.columns)
# Out:
# Index(['user_id', 'age', 'Age_categories', 'country', 'city',
#        'user_settings_crypto_unlocked', 'plan',
#        'attributes_notifications_marketing_push',
#        'attributes_notifications_marketing_email', 'num_contacts',
#        'num_referrals', 'num_successful_referrals', 'created_date',
#        'num_logins'],
#       dtype='object')

# %% [markdown]
# # Hypothesis(1)💡🧪

# %%
import pandas as pd
df = pd.read_csv('/content/Hypothesis 1.csv')
print(df.head())
# Out:
#   churn_status  avg_transactions
# 0       active        206.582065
# 1      churned         19.917607
# 2      at_risk         35.245714
# 3      regular         66.079691

# %%
import plotly.express as px


fig = px.bar(df, x='churn_status', y='avg_transactions', title='Average Transactions by Churn Status',
             labels={'churn_status': 'Churn Status', 'avg_transactions': 'Average Transactions'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/haypothesis-1.csv')
print(df.head())
# Out:
#   churn_status  avg_transactions
# 0       active        206.582065
# 1      churned         19.917607
# 2      regular         66.079691
# 3      at_risk         35.245714

# %%
# Calculate quartiles and IQR
Q1 = df['avg_transactions'].quantile(0.25)
Q3 = df['avg_transactions'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_churned = df[(df['churn_status'] == 'churned') & ((df['avg_transactions'] < lower_bound) | (df['avg_transactions'] > upper_bound))]
outliers_active = df[(df['churn_status'] == 'active') & ((df['avg_transactions'] < lower_bound) | (df['avg_transactions'] > upper_bound))]

print("Outliers in churned users:")
print(outliers_churned)

print("Outliers in active users:")
print(outliers_active)
# Out:
# Outliers in churned users:
# Empty DataFrame
# Columns: [churn_status, avg_transactions]
# Index: []
# Outliers in active users:
#   churn_status  avg_transactions
# 0       active        206.582065

# %%
import plotly.express as px


fig = px.box(df, x='churn_status', y='avg_transactions', title='Box Plot of Average Transactions by Churn Status',
             labels={'churn_status': 'Churn Status', 'avg_transactions': 'Average Transactions'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Hypothesis(2)💡🧪

# %%
import pandas as pd
df = pd.read_csv("/content/bquxjob_226095a4_18ee6dc64e7.csv")
print(df.head())
# Out:
#          crypto_status  avg_transactions
# 0  Not Unlocked Crypto        115.978697
# 1      Unlocked Crypto        254.337788

# %%
import plotly.express as px

# Create a bar plot
fig = px.bar(df, x='crypto_status', y='avg_transactions', title='Average Transactions by  crypto_status',
             labels={'crypto_status': 'Crypto Status', 'avg_transactions': 'Average Transactions'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Hypothesis(3)💡🧪

# %%
import pandas as pd
import plotly.express as px

# Load the CSV file into a DataFrame
df = pd.read_csv('/content/bquxjob_56bc05a6_18ee6e0420a.csv')

# Visualize the relationship between referral behavior and churn rate
fig = px.bar(df, x='referral_behavior', y='churn_rate',
             title='Churn Rate by Referral Behavior',
             labels={'referral_behavior': 'Referral Behavior', 'churn_rate': 'Churn Rate'})
fig.show()
# Out:
# Index(['referral_behavior', 'churned_users', 'total_users', 'churn_rate'], dtype='object')
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Hypothesis(4)💡🧪

# %%
import pandas as pd
df = pd.read_csv("/content/bq-results-20240417-030549-1713323164785.csv")
print(df.head())
# Out:
#   Age_categories            city  avg_transactions  churn_rate
# 0            30s       Milisauti            2598.0           0
# 1            60s       BLACKROCK            2192.0           0
# 2            50s  Upplands Väsby            2101.0           0
# 3            40s         CHERISY            2053.0           0
# 4            20s       Worcester            1872.0           0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Age_categories'], df['avg_transactions'])
plt.title('Average Transactions by Age Category')
plt.xlabel('Age Category')
plt.ylabel('Average Transactions')
plt.show()

# %%
import plotly.express as px

fig = px.scatter(df, x='city', y='Age_categories', size='avg_transactions',
                 color='Age_categories', title='Average Transactions by City and Age Category',
                 labels={'avg_transactions': 'Average Transactions', 'city': 'City'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/nexGen_info.csv")
print(df.head())
# Out:
#       user_id       transaction_id user_status  age Age_categories country  \
# 0  user_11598  transaction_2035755     regular   23            20s      PL
# 1   user_6202   transaction_185392     regular   23            20s      GB
# 2   user_4559  transaction_1493596      active   23            20s      GB
# 3  user_17657  transaction_2735042      active   23            20s      LV
# 4  user_12679  transaction_2731721      active   23            20s      MT
#
#               city        crypto_status      plan  \
# 0      Chwaszczyno  Not Unlocked Crypto  STANDARD
# 1  Hemel Hempstead  Not Unlocked Crypto  STANDARD
# 2      Fraserburgh  Not Unlocked Crypto  STANDARD
# 3             Rīga  Not Unlocked Crypto  STANDARD
# 4           Attard  Not Unlocked Crypto  STANDARD
#
#    notifications_marketing_push  ...  transactions_currency  amount_usd  \
# 0                           1.0  ...                    PLN      127.25
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a stacked bar chart
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Age_categories', hue='user_status')
plt.title('Distribution of User Status by Age Categories')
plt.xlabel('Age Categories')
plt.ylabel('Count')
plt.legend(title='User Status')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get the top 10 cities by frequency
top_cities = df['city'].value_counts().head(10).index

# Filter the DataFrame to include only the top `10 cities
df_top_cities = df[df['city'].isin(top_cities)]

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.countplot(data=df_top_cities, x='city', hue='Age_categories')
plt.title('Distribution of Age Categories in Top Cities')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Age Categories')
plt.tight_layout()
plt.show()

# %%
def determine_user_status(row):
    if (row['user_status'] == 'regular' or row['user_status'] == 'active') and row['num_transactions'] > 0:
        return 1
    else:
        return 0

df['user_active'] = df.apply(determine_user_status, axis=1)
print(df.head())
# Out:
#       user_id       transaction_id user_status  age Age_categories country  \
# 0  user_11598  transaction_2035755     regular   23            20s      PL
# 1   user_6202   transaction_185392     regular   23            20s      GB
# 2   user_4559  transaction_1493596      active   23            20s      GB
# 3  user_17657  transaction_2735042      active   23            20s      LV
# 4  user_12679  transaction_2731721      active   23            20s      MT
#
#               city        crypto_status      plan  \
# 0      Chwaszczyno  Not Unlocked Crypto  STANDARD
# 1  Hemel Hempstead  Not Unlocked Crypto  STANDARD
# 2      Fraserburgh  Not Unlocked Crypto  STANDARD
# 3             Rīga  Not Unlocked Crypto  STANDARD
# 4           Attard  Not Unlocked Crypto  STANDARD
#
#    notifications_marketing_push  ...  amount_usd  transactions_state  \
# 0                           1.0  ...      127.25            REVERTED
# 1                           1.0  ...      104.00            DECLINED
# ...

# %% [markdown]
# #Correlation Metrics📊

# %%
import seaborn as sns
from scipy.stats import pearsonr

numerical_cols = ['age', 'num_transactions', 'amount_usd', 'num_notifications','user_active']
correlation_matrix = df[numerical_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

for col1 in numerical_cols:
    for col2 in numerical_cols:
        if col1 != col2:
            correlation, p_value = pearsonr(df[col1], df[col2])
            print(f"Pearson correlation coefficient between {col1} and {col2}: {correlation:.2f}, p-value: {p_value:.4f}")
# Out:
# Pearson correlation coefficient between age and num_transactions: -0.11, p-value: 0.0000
# Pearson correlation coefficient between age and amount_usd: -0.01, p-value: 0.0671
# Pearson correlation coefficient between age and num_notifications: -0.08, p-value: 0.0000
# Pearson correlation coefficient between age and user_active: -0.05, p-value: 0.0000
# Pearson correlation coefficient between num_transactions and age: -0.11, p-value: 0.0000
# Pearson correlation coefficient between num_transactions and amount_usd: 0.01, p-value: 0.0611
# Pearson correlation coefficient between num_transactions and num_notifications: 0.86, p-value: 0.0000
# Pearson correlation coefficient between num_transactions and user_active: 0.28, p-value: 0.0000
# Pearson correlation coefficient between amount_usd and age: -0.01, p-value: 0.0671
# Pearson correlation coefficient between amount_usd and num_transactions: 0.01, p-value: 0.0611
# ...

# %% [markdown]
# ##**Predictions🤖**

# %%
import pandas as pd
df_ML = pd.read_csv("/content/NexGen Bank.csv")
print(df_ML.head())
# Out:
#       user_id transaction_id   age Age_categories country              city  \
# 0  user_15225            NaN  26.0            20s  Poland      Tyczyn gmina
# 1  user_16067            NaN  42.0            40s  France  Challes-les-Eaux
# 2  user_11220            NaN  29.0            20s  Greece       Argyroupoli
# 3    user_365            NaN  25.0            20s  France           Limoges
# 4  user_10411            NaN  44.0            40s  France           Trappes
#
#          crypto_status  avg_transactions  num_transactions      plan  ...  \
# 0  Not Unlocked Crypto               0.0                 0  STANDARD  ...
# 1  Not Unlocked Crypto               0.0                 0  STANDARD  ...
# 2  Not Unlocked Crypto               0.0                 0  STANDARD  ...
# 3  Not Unlocked Crypto               0.0                 0  STANDARD  ...
# 4  Not Unlocked Crypto               0.0                 0  STANDARD  ...
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import AdaBoostClassifier

from sklearn.model_selection import GridSearchCV

X_ML=df_ML.drop(['user_status'],axis=1)
y_ML = df_ML['user_status']

X_train, X_test, y_train, y_test = train_test_split(X_ML, y_ML, test_size=0.3)

model = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=2,

                                                         max_features='auto',

                                                         min_samples_leaf=5,

                                                         random_state=11))
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)


engagement = pd.Series(y_pred).value_counts()
labels = engagement.index.tolist()
values = engagement.values.tolist()
colors = ['dodgerblue', 'turquoise', 'magenta', 'darkorange']


plt.pie(values, labels=labels, autopct='%1.1f%%', colors=colors)
plt.title("User type Predictions")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-0ee13080e369> in <cell line: 26>()
#      24
#      25                                                          random_state=11))
# ---> 26 model.fit(X_train, y_train)
#      27
#      28 y_pred = model.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py in fit(self, X, y, sample_weight)
#     124         self._validate_params()
#     125
# --> 126         X, y = self._validate_data(
#     127             X,
#     128             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
# ...
